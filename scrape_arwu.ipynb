# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
r = requests.get("https://www.shanghairanking.com/rankings/arwu/2023")

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
table = soup.find_all("table", {"class": "rk-table"})

# %%
table[0]
# Out:
# <table class="rk-table" data-v-ae1ab4a8=""><thead data-v-ae1ab4a8=""><tr data-v-ae1ab4a8=""><th data-v-ae1ab4a8="" style="width:70px"> World
# Rank </th><th class="align-left" data-v-ae1ab4a8="" style="width:auto">
# Institution
# ...

# %%
df = pd.read_html("https://www.shanghairanking.com/rankings/arwu/2023", attrs={"class": "rk-table"})

# %%
df[0][["World Rank", "Insitution"]]
# Out:
#     World Rank                                  Institution  Unnamed: 2  \
# 0            1                           Harvard University         NaN
# 1            2                          Stanford University         NaN
# 2            3  Massachusetts Institute of Technology (MIT)         NaN
# 3            4                      University of Cambridge         NaN
# 4            5           University of California, Berkeley         NaN
# 5            6                         Princeton University         NaN
# 6            7                         University of Oxford         NaN
# 7            8                          Columbia University         NaN
# 8            9           California Institute of Technology         NaN
# 9           10                        University of Chicago         NaN
# 10          11                              Yale University         NaN
# 11          12                           Cornell University         NaN
# ...

# %%
base_url = "https://www.shanghairanking.com/_nuxt/static/1710222395/rankings/arwu/%d/payload.js"
years = list(i for i in range(2003, 2024))
years
# Out:
# [2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023]

# %%
for y in years:
    path = base_url % y
    content = requests.get(path)
    with open(f"arwu_raw_{y}.js", "w") as file:
        file.write(content.text)
